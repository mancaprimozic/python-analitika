# %% [markdown]
# # Uvod

# %%
#omogoča interaktivnost grafov
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## pyplot
#
#
# ## The Matplotlib Object Hierarchy

# %% [markdown]
# ## Hierarhija objektov matplotlib
# FIGURE - okvir
#
# FIGURE-u dodajamo  AXES (SUBPLOT)
#
# AXESu dodajamo lastnosti TICK, LINES, LEGEND

# %% [markdown]
# ### Simple plot

# %%
import numpy as np

x = np.linspace(-np.pi, np.pi, 256)

C = np.cos(x)
S = np.sin(x)

# %%
#izrišemo sin in cos v isti graf
#matplotlib ima že ene defaultne nastvavittve, ki jih uporabi, če mu nič ne nastavimo

#najprej definiramo figure, vsa koda, ki jo pišem pod figure, se navezuje na ta figure (
#dokler ne definiramo novega figure-a)
plt.figure()

#oba grafa damo na isti figure
#uporabijo se default nastaviteve osi
plt.plot(S)
plt.plot(C)

#prikaz grafa
plt.show
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ### Matplotlib - osnovne lastnosti

# %%
# !head -n 3 data/DATA_percent-bachelors-degrees-women-usa.csv
# Out:
# Year,Agriculture,Architecture,Art and Performance,Biology,Business,Communications and Journalism,Computer Science,Education,Engineering,English,Foreign Languages,Health Professions,Math and Statistics,Physical Sciences,Psychology,Public Administration,Social Sciences and History
# 1970,4.22979798,11.92100539,59.7,29.08836297,9.064438975,35.3,13.6,74.53532758,0.8,65.57092343,73.8,77.1,38,13.8,44.4,68.4,36.8
# 1971,5.452796685,12.00310559,59.9,29.39440285,9.503186594,35.5,13.6,74.14920369,1,64.55648516,73.9,75.5,39,14.9,46.2,65.5,36.2

# %%
import csv
import numpy as np

year = list()
physical_sciences = list()
computer_science = list()
health = list()
education = list()

with open('data/DATA_percent-bachelors-degrees-women-usa.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        year.append(int(row['Year']))
        physical_sciences.append(float(row['Physical Sciences']))
        computer_science.append(float(row['Computer Science']))
        health.append(float(row['Health Professions']))
        education.append(float(row['Education']))

year = np.array(year)    
physical_sciences = np.array(physical_sciences)    
computer_science = np.array(computer_science)    
health = np.array(health)    
education = np.array(education)

# %% [markdown]
# **Figures**

# %%
#okvir
plt.figure(figsize = (8,6), dpi = 80)
plt.plot(year, physical_sciences, c = 'blue')
plt.plot(year, computer_science, c = 'red')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# **Axes**

# %%
#naredimo 2 okvirja: vsak graf narišemo v svoj okvir
#pri subplotu povemo, na koliko delov razdelimo in potem se avtomatsko postavijo 
#pri axisu pa  povemo relativno lego grafov

# %%
plt.figure(figsize = (8,6), dpi = 80)

#prvi axes
plt.axes([0.05, 0.05, 0.425, 0.9]) #okvir,kjer bo notri naš graf
plt.plot(year, physical_sciences, c = 'blue')

#drugi axes
plt.axes([0.525, 0.05, 0.425, 0.9]) #okvir,kjer bo notri naš graf
plt.plot(year, computer_science, c = 'red')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# **Subplots**

# %%
#povemo samo vrstni red grafov, ni treba relatvine lege napisat, avtomatsko jih postavi
plt.figure(figsize=(8,6), dpi=80)

plt.subplot(1,2,1)
plt.plot(year, physical_sciences, c = 'blue')
plt.title('Physical Sciences')


plt.subplot(1,2,2)
plt.plot(year, computer_science, c = 'red')
plt.title('Computer Sciences')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.subplot(2,2,1)
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')


plt.subplot(2,2,2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')


plt.subplot(2,2,3)
plt.plot(year, health, color='green')
plt.title('Health Professions')


plt.subplot(2,2,4)
plt.plot(year, education, color='yellow')
plt.title('Education')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# **Customizing axes (osi)**

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.plot(year,computer_science, color='red') 
plt.plot(year, physical_sciences, color='blue')

#ime osi
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')


#lahko določimo, od koliko do koliko vrednosti nam kaže na x in y osi
plt.xlim(1990,2010)
plt.ylim(0,50)

#naslov
plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nPhysical Sciences (blue)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
plt.figure(figsize=(8,6), dpi=80)

plt.plot(year,computer_science, color='blue')
plt.plot(year, physical_sciences,color='red')

#isto kot xlim, ylim
plt.axis((1990,2010,0,50))
plt.show()

#shranimo sliko
plt.savefig('myfig.png')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# **Using legend()**

# %%
plt.figure(figsize=(8,6), dpi=80)

#ko dodajamo legendo, moramo vedno dodati label
#label se poveže z barvo in iz tega se potem naredi legenda
plt.plot(year, computer_science, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')

plt.legend(loc = 'lower center')
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

plt.title('Undergraduate enrollment of women')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# **Using annotate()**

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.plot(year, computer_science, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')
plt.legend(loc='lower center')

#maximum poiščemo - dobimo  koordinato (x,y)
#to točko bi radi označili na grafu
cs_max = computer_science.max()
yr_max = year[computer_science.argmax()]

plt.annotate('Maximum ', xy = (yr_max, cs_max), xytext = (yr_max+5, cs_max+5), arrowprops = dict(facecolor='black'))


plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# **Modifying styles**

# %%
print(plt.style.available)
# Out:
# ['classic', 'seaborn-deep', 'dark_background', 'seaborn-colorblind', 'bmh', 'grayscale', 'Solarize_Light2', 'seaborn-dark-palette', 'seaborn-whitegrid', 'seaborn-ticks', 'seaborn-paper', 'seaborn-pastel', 'fivethirtyeight', 'seaborn-white', 'seaborn-talk', 'seaborn-poster', 'seaborn', 'ggplot', 'seaborn-darkgrid', '_classic_test', 'fast', 'seaborn-bright', 'tableau-colorblind10', 'seaborn-muted', 'seaborn-notebook', 'seaborn-dark']

# %%
plt.figure(figsize=(8,6), dpi=80)

#določimo stil
plt.style.use('ggplot')




plt.subplot(2, 2, 1) 
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(2, 2, 2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

cs_max = computer_science.max()
yr_max = year[computer_science.argmax()]
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max-1, cs_max-10), arrowprops=dict(facecolor='black'))


plt.subplot(2, 2, 3)
plt.plot(year, health, color='green')
plt.title('Health Professions')


plt.subplot(2, 2, 4)
plt.plot(year, education, color='yellow')
plt.title('Education')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# **Ticks**

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.plot(year, computer_science, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')


plt.legend(loc='lower center')


plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')

#definiramo, točno katere številke naj bodo zapisane na x in y osi
plt.xticks(np.linspace(1970,2015,10, endpoint= True)) #cifre od 1970 do 2015 razdeli na 10 delov, vključi 2015
plt.yticks(np.linspace(0,50,26,endpoint = True))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ### Vrste grafov

# %%
#Regular Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plt.axes([0.025,0.025,0.95,0.95])

plt.plot (X, Y+1, color='blue', alpha=1.00)
plt.fill_between(X, 1, Y+1, color='blue', alpha=.25)

plt.plot (X, Y-1, color='blue', alpha=1.00)
plt.fill_between(X, -1, Y-1, (Y-1) > -1, color='blue', alpha=.25)
plt.fill_between(X, -1, Y-1, (Y-1) < -1, color='red',  alpha=.25)

plt.xlim(-np.pi,np.pi), plt.xticks([])
plt.ylim(-2.5,2.5), plt.yticks([])
# savefig('../figures/plot_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="479.4166666666667">

# %%
#Scatter Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T = np.arctan2(Y,X)

plt.axes([0.025,0.025,0.95,0.95])
plt.scatter(X,Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5,1.5), plt.xticks([])
plt.ylim(-1.5,1.5), plt.yticks([])
# savefig('../figures/scatter_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="479.4166666666667">

# %%
#Bar Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

plt.axes([0.025,0.025,0.95,0.95])
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

for x,y in zip(X,Y2):
    plt.text(x+0.4, -y-0.05, '%.2f' % y, ha='center', va= 'top')

plt.xlim(-.5,n), plt.xticks([])
plt.ylim(-1.25,+1.25), plt.yticks([])

# savefig('../figures/bar_ex.png', dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="479.4166666666667">

# %%
#Contour Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

def f(x,y):
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

plt.axes([0.025,0.025,0.95,0.95])

plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap=plt.cm.hot)
C = plt.contour(X, Y, f(X,Y), 8, colors='black')
plt.clabel(C, inline=1, fontsize=10)

plt.xticks([]), plt.yticks([])
# savefig('../figures/contour_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="479.4166666666667">

# %%
#Pie Charts
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 20
Z = np.ones(n)
Z[-1] *= 2

plt.axes([0.025,0.025,0.95,0.95])

plt.pie(Z, explode=Z*.05, colors = ['%f' % (i/float(n)) for i in range(n)])
plt.gca().set_aspect('equal')
plt.xticks([]), plt.yticks([])

# savefig('../figures/pie_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="479.4166666666667">

# %%
#Polar Axis
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

ax = plt.axes([0.025,0.025,0.95,0.95], polar=True)

N = 20
theta = np.arange(0.0, 2*np.pi, 2*np.pi/N)
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
bars = plt.bar(theta, radii, width=width, bottom=0.0)

for r,bar in zip(radii, bars):
    bar.set_facecolor( plt.cm.jet(r/10.))
    bar.set_alpha(0.5)

ax.set_xticklabels([])
ax.set_yticklabels([])
# savefig('../figures/polar_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="479.4166666666667">

# %% [markdown]
# ### Ploting two-dimensional arrays

# %% [markdown]
# **Generating meshes**

# %%
import numpy as np
Y,X = np.meshgrid(range(10),range(20))

# %%
plt.figure(figsize=(6,4), dpi=80)


u = np.linspace(-2, 2, 41)
v = np.linspace(-1, 1, 21)

X, Y = np.meshgrid(u,v)
Z = np.sin(3*np.sqrt(X**2 + Y**2))


plt.pcolor(Z)
plt.show()

# %% [markdown]
# **Contour & filled contour plots**

# %%
plt.figure(figsize=(6,4), dpi=80)

plt.subplot(2,2,1)
plt.contourf(X,Y,Z,20, cmap='viridis')
plt.colorbar()
plt.title('Viridis')


plt.subplot(2,2,2)
plt.contourf(X,Y,Z,20, cmap='gray')
plt.colorbar()
plt.title('Gray')


plt.subplot(2,2,3)
plt.contourf(X,Y,Z,20, cmap='autumn')
plt.colorbar()
plt.title('Autumn')


plt.subplot(2,2,4)
plt.contourf(X,Y,Z,20, cmap='winter')
plt.colorbar()
plt.title('Winter')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analiza časovnih vrst

# %% [markdown]
# ***Multiple time series on common axes***

# %%
#priprava podatkov
import pandas as pd

# %%
stocks = pd.read_csv('data/DATA_stocks.csv')
stocks.head()
# Out:
#          Date        AAPL       IBM      CSCO      MSFT
# 0  2000-01-03  111.937502  116.0000  108.0625  116.5625
# 1  2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2  2000-01-05  103.999997  116.0000  101.6875  113.8125
# 3  2000-01-06   94.999998  114.0000  100.0000  110.0000
# 4  2000-01-07   99.500001  113.5000  105.8750  111.4375

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521 entries, 0 to 3520
# Data columns (total 5 columns):
# Date    3521 non-null object
# AAPL    3521 non-null float64
# IBM     3521 non-null float64
# CSCO    3521 non-null float64
# MSFT    3521 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 137.6+ KB

# %%
#stolpec Date pretvorimo v datetime
stocks['Date'] = pd.to_datetime(stocks['Date'])
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3521 entries, 2000-01-03 to 2013-12-31
# Data columns (total 5 columns):
# Date    3521 non-null datetime64[ns]
# AAPL    3521 non-null float64
# IBM     3521 non-null float64
# CSCO    3521 non-null float64
# MSFT    3521 non-null float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 165.0+ KB

# %%
#stolpec Date bomo uporabili za indeks
stocks = stocks.set_index('Date', drop = True)
stocks.head()
# Out:
#                   AAPL       IBM      CSCO      MSFT
# Date
# 2000-01-03  111.937502  116.0000  108.0625  116.5625
# 2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2000-01-05  103.999997  116.0000  101.6875  113.8125
# 2000-01-06   94.999998  114.0000  100.0000  110.0000
# 2000-01-07   99.500001  113.5000  105.8750  111.4375

# %%
aapl = stocks['AAPL']
ibm = stocks['IBM']
csco = stocks['CSCO']
msft = stocks['MSFT']

# %%
plt.figure(figsize=(6,4), dpi=80)

#appl
plt.plot(aapl, color='blue', label = 'AAPL')
plt.plot(ibm, color='green', label='IBM')
plt.plot(csco, color='red', label='CSCO')
plt.plot(msft, color='magenta', label='MSFT')


plt.legend(loc='upper left')
plt.xticks(rotation=60)
plt.show()
# Out:
# /home/manca/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Multiple time series slices**

# %%
plt.figure(figsize=(6,4), dpi=80)

#cela časovna serija
plt.subplot(2,1,1)
plt.xticks(rotation=45) #rotation obrne številke, napiše jih pod kotom 45
plt.title('AAPL: All time')
plt.plot(aapl, color='blue')


#izberemo samo časovno obdobje med 2007 in 2008 (vključno z 2008)
view = aapl['2007':'2008']
plt.subplot(2,1,2)
plt.xticks(rotation=45) 
plt.title('AAPL: 2007 to 2008')
plt.plot(view, color = 'black')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4), dpi=80)

#lahko izbiramo tudi mesece + leta
view = aapl['2007-11':'2008-04']


plt.subplot(2,1,1)
plt.plot(view, color='red')
plt.title('AAPL: Nov. 2007 to Apr. 2008')
plt.xticks(rotation=45)

#pokažemo samo januar
view = aapl['2008-01']


plt.subplot(2,1,2)
plt.plot(view, color='green')
plt.title('AAPL: Jan. 2008')
plt.xticks(rotation=45)


plt.tight_layout()
plt.show()

# %% [markdown]
# **Plotting an inset view**

# %%
plt.figure(figsize=(6,4), dpi=80)

view = aapl['2007-11':'2008-04']


plt.plot(aapl)
plt.xticks(rotation=45)
plt.title('AAPL: 2001-2011')

#drug graf na isti sliki, določimo mu pozicijo
plt.axes([0.25,0.5, 0.35, 0.30])


plt.plot(view, color='red')
plt.xticks(rotation=45)
plt.title('2007/11-2008/04')
plt.show()

# %% [markdown]
# ### Pandas df.plot

# %% [markdown]
# #### Data preparation
#
# [OECD](https://data.oecd.org/unemp/unemployment-rate.htm)

# %%
oecd = pd.read_csv('data/DATA_oecd.csv')
# oecd.info()
# oecd.head()

columns_to_drop = ['INDICATOR', 'SUBJECT','FREQUENCY','MEASURE', 'Flag Codes']
oecd.drop(columns=columns_to_drop, inplace=True)

# %%
oecd.head()
# Out:
#   LOCATION  TIME     Value
# 0      AUS  1986  8.081038
# 1      AUS  1987  8.108040
# 2      AUS  1988  7.227954
# 3      AUS  1989  6.179825
# 4      AUS  1990  6.923000

# %% [markdown]
# #### pandas vs matplotlib

# %% [markdown]
# #### Which .plot do I use?

# %% [markdown]
# #### Plotting Version 1: .plot plots the index against every column

# %%
oecd[35:40]
# Out:
#    LOCATION  TIME     Value
# 35      AUT  1988  3.563734
# 36      AUT  1989  3.132628
# 37      AUT  1990  3.240462
# 38      AUT  1991  3.475676
# 39      AUT  1992  3.593146

# %%
#plot brez parametrov po defaultu vzame index za x os in ostale stolpce poskuša narisat
#nariše vse stolpce, ki so številski in jih lahko nariše
oecd.plot()

# %%
#povprečna vrednost brezposelnosti po državah
mean_val = oecd.groupby('LOCATION')['Value'].mean()
mean_val
# Out:
# LOCATION
# AUS    6.725630
# AUT    4.396571
# BEL    7.727318
# CAN    7.954041
# Name: Value, dtype: float64

# %%
#zrišemo
mean_val.plot(kind = 'bar')

# %% [markdown]
# #### Plotting Version 2: .plot(x='col1') plots against a single specific column
#
# Več o tem v naslednjem poglaviju.
#
# #### Plotting Version 3: .plot(x='col1', y='col2') plots one specific column against another specific column

# %%
#določimo x in y os
oecd.plot(x= 'TIME', y = 'Value')
#gre po vrsti po državah in vse države med sabo poveže (ravna črta je povezava med dražvami)

# %%
#ločimo po državah
oecd.groupby('LOCATION').plot(x= 'TIME', y = 'Value')

#grafi so pravilni, ampak nariše 4 grafe (za vsako državo posebej)
# Out:
# LOCATION
# AUS    AxesSubplot(0.125,0.125;0.775x0.755)
# AUT    AxesSubplot(0.125,0.125;0.775x0.755)
# BEL    AxesSubplot(0.125,0.125;0.775x0.755)
# CAN    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
#radi bi združili vse grafe v isti figure- pomagamo si matplotlib ax
fig, ax = plt.subplots()
oecd.groupby('LOCATION').plot(x= 'TIME', y = 'Value', ax = ax, legend = False)
# Out:
# LOCATION
# AUS    AxesSubplot(0.125,0.125;0.775x0.755)
# AUT    AxesSubplot(0.125,0.125;0.775x0.755)
# BEL    AxesSubplot(0.125,0.125;0.775x0.755)
# CAN    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# #### Primeri

# %% [markdown]
# ##### Basic Plotting: plot

# %%
df = pd.DataFrame(np.random.randn(10,4),
                  index=pd.date_range('1/1/2000',periods=10), 
                  columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.821552 -1.601883 -0.080975  0.436627
# 2000-01-02  0.265998  1.168321 -0.170962 -0.133522
# 2000-01-03  0.485172  1.332621 -0.681456  1.728457
# 2000-01-04 -0.024129 -1.208650  1.326286 -0.184347
# 2000-01-05  1.250030 -0.716046  0.388620 -1.894766
# 2000-01-06 -0.190496 -0.312719  0.439055 -0.107357
# 2000-01-07  0.709272  0.696722  0.467382  1.358482
# 2000-01-08 -0.728757 -0.086170  1.052955 -0.509878
# 2000-01-09 -0.183223 -1.395329  0.511048  0.086494
# 2000-01-10 -0.559961  1.019172 -1.123132 -0.603957

# %%
#
df.plot()

# %% [markdown]
# ##### Bar Plot

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
#stacked jih zlepi skupaj
#barh jih nariše vodoravno
df.plot(kind='barh', stacked=True)

# %% [markdown]
# ### seaborn: statistical data visualization
#
# > [Seaborn dokumentacija](https://seaborn.pydata.org/)

# %%
#višjenivojska knjižnica za prikazovanje statističnih obdelav

# %% [markdown]
# **Simple linear regressions**

# %%
#uvoz podatkov
import pandas as pd

auto = pd.read_csv('data/DATA_auto-mpg.csv')
auto.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size marker
# 0  27.370336      o
# 1  62.199511      o
# 2   9.000000      x
# 3  34.515625      o
# 4  13.298178      s

# %%
#narisali bomo graf odvisnosti števila konjev in teže
import seaborn as sns

#lmplot - linearna regresija
sns.lmplot(data = auto, x= 'weight', y = 'hp')
